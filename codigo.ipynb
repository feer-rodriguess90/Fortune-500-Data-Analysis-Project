# %%
#LIBRARIES
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np
import streamlit as st

# %%
#LOAD AND DISPLAY THE FIRST FEW  DATASET 
df = pd.read_csv('./fortune1000_2023.csv')
df.head(5)
# Out:
#    Rank             Company Ticker       Sector  \
# 0     1             Walmart    WMT    Retailing
# 1     2              Amazon   AMZN    Retailing
# 2     3         Exxon Mobil    XOM       Energy
# 3     4               Apple   AAPL   Technology
# 4     5  UnitedHealth Group    UNH  Health Care
#
#                                   Industry Profitable Founder_is_CEO  \
# 0                    General Merchandisers        yes             no
# 1          Internet Services and Retailing         no             no
# 2                       Petroleum Refining        yes             no
# 3              Computers, Office Equipment        yes             no
# 4  Health Care: Insurance and Managed Care        yes             no
#
#   FemaleCEO Growth_in_Jobs  Change_in_Rank  ... Assets_M                  CEO  \
# 0        no             no             0.0  ...   243197  C. Douglas McMillon
# 1        no             no             0.0  ...   462675      Andrew R. Jassy
# ...

# %%
#Quantitative data exploration
print("Size of data:", df.size)
print("Shape of data:", df.shape)
# Out:
# Size of data: 31000
# Shape of data: (1000, 31)

# %%
#Display summary statistics for numerical variables 
#quantitative data exploration
print("Data Description")
df.describe()
# Out:
# Data Description
#               Rank  Change_in_Rank  Number_of_employees  MarketCap_March31_M  \
# count  1000.000000      929.000000         1.000000e+03         9.590000e+02
# mean    500.498000        0.244349         3.646411e+04         3.967218e+04
# std     288.820355       65.525393         9.980620e+04         1.383292e+05
# min       1.000000     -431.000000         2.300000e+01         1.200000e+01
# 25%     250.750000      -26.000000         6.660750e+03         3.994000e+03
# 50%     500.500000       -3.000000         1.417000e+04         1.015800e+04
# 75%     750.250000       20.000000         3.101000e+04         3.220000e+04
# max    1000.000000      342.000000         2.100000e+06         2.609039e+06
#
#           Revenues_M  RevenuePercentChange     Profits_M  \
# count    1000.000000            991.000000   1000.000000
# mean    20274.218000             18.540565   1725.548000
# std     45905.041289             42.004907   5869.237142
# ...

# %%
#Qualitative data exploration 
print("Column names of the attributes:\n", df.columns)
# Out:
# Column names of the attributes:
#  Index(['Rank', 'Company', 'Ticker', 'Sector', 'Industry', 'Profitable',
#        'Founder_is_CEO', 'FemaleCEO', 'Growth_in_Jobs', 'Change_in_Rank',
#        'Gained_in_Rank', 'Dropped_in_Rank', 'Newcomer_to_the_Fortune500',
#        'Global500', 'Best_Companies', 'Number_of_employees',
#        'MarketCap_March31_M', 'Revenues_M', 'RevenuePercentChange',
#        'Profits_M', 'ProfitsPercentChange', 'Assets_M', 'CEO', 'Country',
#        'HeadquartersCity', 'HeadquartersState', 'Website', 'CompanyType',
#        'Footnote', 'MarketCap_Updated_M', 'Updated'],
#       dtype='object')

# %%
#Qualitative data exploration
print("Data types of the attributes:",df.dtypes)
# Out:
# Data types of the attributes: Rank                            int64
# Company                        object
# Ticker                         object
# Sector                         object
# Industry                       object
# Profitable                     object
# Founder_is_CEO                 object
# FemaleCEO                      object
# Growth_in_Jobs                 object
# Change_in_Rank                float64
# Gained_in_Rank                 object
# Dropped_in_Rank                object
# Newcomer_to_the_Fortune500     object
# Global500                      object
# Best_Companies                 object
# Number_of_employees             int64
# MarketCap_March31_M           float64
# Revenues_M                      int64
# RevenuePercentChange          float64
# Profits_M                       int64
# ProfitsPercentChange          float64
# Assets_M                        int64
# CEO                            object
# Country                        object
# ...

# %%
# Display information about the dataset, including data types and non-null counts
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 31 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Rank                        1000 non-null   int64
#  1   Company                     1000 non-null   object
#  2   Ticker                      959 non-null    object
#  3   Sector                      1000 non-null   object
#  4   Industry                    1000 non-null   object
#  5   Profitable                  1000 non-null   object
#  6   Founder_is_CEO              1000 non-null   object
#  7   FemaleCEO                   1000 non-null   object
#  8   Growth_in_Jobs              993 non-null    object
#  9   Change_in_Rank              929 non-null    float64
#  10  Gained_in_Rank              929 non-null    object
#  11  Dropped_in_Rank             929 non-null    object
#  12  Newcomer_to_the_Fortune500  500 non-null    object
# ...

# %%
# Check the dataset for missing values
# Leverage the isnull() and sum() functions to find the number of missing values in each column
missing_values = df.isnull().sum()

# urn the missing value counts into percentages
missing_values_percentage = (missing_values / len(df)) * 100

# Return counts and percentages of missing values in each column
missing_data = pd.DataFrame({'Missing Values': missing_values, 'Percentage (%)': missing_values_percentage})
missing_data.sort_values(by='Percentage (%)', ascending=False)
# Out:
#                             Missing Values  Percentage (%)
# Newcomer_to_the_Fortune500             500            50.0
# ProfitsPercentChange                   134            13.4
# Change_in_Rank                          71             7.1
# Dropped_in_Rank                         71             7.1
# Gained_in_Rank                          71             7.1
# Ticker                                  41             4.1
# MarketCap_March31_M                     41             4.1
# MarketCap_Updated_M                     35             3.5
# RevenuePercentChange                     9             0.9
# Footnote                                 9             0.9
# Growth_in_Jobs                           7             0.7
# CEO                                      1             0.1
# HeadquartersState                        0             0.0
# Website                                  0             0.0
# CompanyType                              0             0.0
# ...

# %% [markdown]
# Here's an overview of the missing values in the dataset: <br>
#  **Newcomer to the Fortune 500:** Companies not included in the Fortune 500 list for the given year, incomplete data extraction or scraping process, or data entry errors. <br>
#  **Profits Percent Change, Revenue Percent Change:** Lack of historical data for some companies, especially if they are newly listed or if the data is not available for the specified period. <br>
#  **Change in Rank, Dropped in Rank, Gained in Rank:** Companies newly included in the Fortune 500 list for the current year, missing historical rank data, or data discrepancies. <br>
# **Ticker, MarketCap March 31, MarketCap Updated** They may not be available for all companies, especially if they are privately held or if the data source does not provide this information, or it may be missing or incomplete in the dataset. <br>
# > * Missing values in the dataset can arise due to various factors such as data availability, extraction methods, and inherent limitations in data sources.

# %%
#Numeric Features 
#Replace the missing values with '0' using 'fiilna' method
df['Change_in_Rank'] = df['Change_in_Rank'].fillna(0)
df['MarketCap_March31_M'] = df['MarketCap_March31_M'].fillna(0)
df['ProfitsPercentChange'] = df['ProfitsPercentChange'].fillna(0)
df['MarketCap_Updated_M'] = df['MarketCap_Updated_M'].fillna(0)
df['RevenuePercentChange'] = df['RevenuePercentChange'].fillna(0)
#Categorical Features 
#Replace the missing values with 'NA' using 'fiilna' method
df['Ticker'] = df['Ticker'].fillna('NA')
df['Gained_in_Rank']=df['Gained_in_Rank'].fillna('NA')
df['Dropped_in_Rank']=df['Dropped_in_Rank'].fillna('NA')
df['Newcomer_to_the_Fortune500']=df['Newcomer_to_the_Fortune500'].fillna('NA')
df['Growth_in_Jobs']=df['Growth_in_Jobs'].fillna('NA')
df['CEO']=df['CEO'].fillna('NA')
df['Footnote']=df['Footnote'].fillna('NA')
df.isna().sum()
# Out:
# Rank                          0
# Company                       0
# Ticker                        0
# Sector                        0
# Industry                      0
# Profitable                    0
# Founder_is_CEO                0
# FemaleCEO                     0
# Growth_in_Jobs                0
# Change_in_Rank                0
# Gained_in_Rank                0
# Dropped_in_Rank               0
# Newcomer_to_the_Fortune500    0
# Global500                     0
# Best_Companies                0
# Number_of_employees           0
# MarketCap_March31_M           0
# Revenues_M                    0
# RevenuePercentChange          0
# Profits_M                     0
# ProfitsPercentChange          0
# Assets_M                      0
# CEO                           0
# Country                       0
# HeadquartersCity              0
# HeadquartersState             0
# Website                       0
# CompanyType                   0
# Footnote                      0
# ...

# %%
# Check for Duplicates after replacement
print("Duplicate Rows:")
df.duplicated().sum()
# Out:
# Duplicate Rows:
# 0

# %% [markdown]
# **DATA VISUALIZATION**

# %% [markdown]
# **Top 10** ranked companies and their respective revenues

# %%
# Sort the DataFrame by rank and select the top 10 companies
top_10_ranked = df.nsmallest(10, 'Rank')

# Plot the bar chart
plt.figure(figsize=(10, 6))
plt.barh(top_10_ranked['Company'], top_10_ranked['Revenues_M'], color='indigo')
plt.xlabel('Revenue ($M)')
plt.ylabel('Company')
plt.title('Top 10 Ranked Companies by Revenue')
plt.show()

# %% [markdown]
# **Top 10** ranked companies and their respective profits

# %%
# Sort the DataFrame by rank and select the top 10 companies
top_10_ranked = df.nsmallest(10, 'Rank')

# Plot the bar chart
plt.figure(figsize=(10, 6))
plt.barh(top_10_ranked['Company'], top_10_ranked['Profits_M'], color='rebeccapurple')
plt.xlabel('Profits ($M)')
plt.ylabel('Company')
plt.title('Top 10 Ranked Companies by Profit')
plt.show()

# %% [markdown]
# **REVENUE x PROFIT**
#
# > * The discrepancy between revenue and profitability highlights the importance of cost management, operational efficiency, and profit margin optimization in determining overall financial health and success.
# > * The dominance of technology companies in terms of profitability underscores the value of innovation, intellectual property, and digital transformation in driving financial success and market leadership.
# > *The energy sector's profitability reflects factors such as global demand for energy, commodity prices, exploration and production activities, and cost management strategies.
# > * High levels of market volatility and investment losses can lead to fluctuations in reported profitability, emphasizing the importance of risk management and diversification in mitigating financial risks. That's the case of Berkshire Hathaway, led by renowned investor Warren Buffett, is known for its diversified investment portfolio.

# %%
# Sort the DataFrame by rank and select the top 10 companies
top_10_ranked = df.nsmallest(10, 'Rank')

# Plot the bar chart
plt.figure(figsize=(10, 6))
plt.bar(top_10_ranked['Company'], top_10_ranked['Number_of_employees'], color='blueviolet')
plt.xlabel('Company')
plt.ylabel('Number of Employees')
plt.title('Number of Employees for Top 10 Ranked Companies')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# **The disparity in the number of employees**
# > * Retail Giants' Workforce Scale: Walmart and Amazon's extensive employee count reflects the vast operational scale of these retail giants. Their large workforce is essential for managing diverse operations, including retail stores, distribution centers, logistics, and customer service.
# > * In contrast, technology company Alphabet (Google's parent company) have leveraged technology and automation to achieve operational efficiency with relatively smaller workforces compared to the revenue and market capitalization.
# > * The ability to achieve significant revenue and market dominance with fewer employees highlights the transformative impact of technology on workforce management and productivity.
# > * Companies in the energy sector, such as Exxon Mobil and Chevron, typically operate large-scale industrial facilities, refineries, and oil fields. The relatively lower number of employees in the energy sector reflects the capital-intensive nature of their operations, where automation, machinery, and specialized equipment play a significant role in production and exploration activities.

# %% [markdown]
# **The top 10 ranked companies and their change in rank compared to the previous year.**

# %%
# Sort the DataFrame by rank and select the top 10 companies
top_10_ranked = df.nsmallest(10, 'Rank')

# Select only the necessary columns
top_10_ranked = top_10_ranked[['Rank', 'Company', 'Sector', 'Change_in_Rank']]
print(top_10_ranked)
# Out:
#    Rank             Company       Sector  Change_in_Rank
# 0     1             Walmart    Retailing             0.0
# 1     2              Amazon    Retailing             0.0
# 2     3         Exxon Mobil       Energy             3.0
# 3     4               Apple   Technology            -1.0
# 4     5  UnitedHealth Group  Health Care             0.0
# 5     6          CVS Health  Health Care            -2.0
# 6     7  Berkshire Hathaway   Financials             0.0
# 7     8            Alphabet   Technology             0.0
# 8     9            McKesson  Health Care             0.0
# 9    10             Chevron       Energy             6.0

# %% [markdown]
# **MOST POPULAR SECTORS**

# %%
#Here we can see the most popular Sectors
sectors = df['Sector'].value_counts()

plt.figure(figsize=(12, 7))
sns.barplot(x=sectors.index, y=sectors.values, hue=sectors.index, palette="magma", legend=False)
plt.title('Most Popular Sectors', fontsize=16)
plt.xlabel('Sectors', fontsize=14)
plt.ylabel('Sectors Values', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# The top 3 Sectors:
# > * Financials
# > * Technology
# > * Energy

# %% [markdown]
# **Here we can see the percentage of profitable companies**

# %%
# Calculate the count of profitable and non-profitable companies
profitable_counts = df['Profitable'].value_counts()

labels = profitable_counts.index
plt.figure(figsize=(8, 6))
plt.pie(profitable_counts, labels=labels, autopct='%1.1f%%', startangle=140, colors=['rebeccapurple', 'burlywood'], explode=[0.05, 0.05])
plt.title('Percentage of Profitable Companies')
plt.legend()
plt.show()

# %% [markdown]
# > * The majority of companies in the dataset are profitable, with 85.9% reporting positive profits. This indicates a healthy business environment overall.
# > * The 14.1% of companies that are not profitable may face challenges such as declining revenue, high expenses, or market disruptions. They may need to reassess their business strategies, operations, and cost structures to improve profitability and long-term sustainability.
# > * Non-profitable companies can leverage insights from profitable peers to identify areas for improvement and implement strategies to enhance financial performance. This may include cost-cutting measures, product innovation, or market expansion efforts.

# %% [markdown]
# **Here we can see the percentage of Female CEO**

# %%
# Calculate the count of female and male CEO
profitable_counts = df['FemaleCEO'].value_counts()

labels = profitable_counts.index
plt.figure(figsize=(8, 6))
plt.pie(profitable_counts, labels=labels, autopct='%1.1f%%', startangle=140, colors=['rebeccapurple', 'burlywood'], explode=[0.05, 0.05])
plt.title('Percentage of Female CEO')
plt.legend()
plt.show()

# %% [markdown]
# **Gender Disparity in Leadership**
# > * The data highlights a significant gender disparity in CEO positions, with a much smaller percentage of companies led by female CEOs compared to male CEOs. This underscores ongoing challenges related to gender diversity and representation in corporate leadership roles.
# > * Factors such as gender stereotypes, lack of mentorship opportunities, and workplace discrimination may contribute to this disparity.
#
# **Impact on Organizational Culture**
# > * The underrepresentation of female CEOs may influence organizational culture and decision-making processes within companies. Diverse leadership teams are associated with better innovation, employee engagement, and financial performance, highlighting the importance of promoting gender diversity at all levels of the organization.
#
# **Role Models and Mentorship**
# > * Increasing the representation of female CEOs can provide positive role models and mentorship opportunities for aspiring women leaders. Visible representation of successful female executives can inspire future generations of women to pursue leadership roles and break down gender barriers in the corporate world.
#
# **Business Performance and Diversity**
# > * Research suggests that companies with diverse leadership teams, including gender-diverse boards and executive suites, tend to outperform their peers in terms of financial performance and innovation. Encouraging gender diversity in CEO positions can contribute to enhanced decision-making and strategic agility, driving long-term business success.

# %% [markdown]
# **The sector and growth in jobs**

# %%
# Group the data by sector and type of growth in jobs
sector_growth = df.groupby(['Sector', 'Growth_in_Jobs']).size().unstack()

# Plot the stacked bar chart
sector_growth.plot(kind='bar', stacked=True, figsize=(10, 6), color = ('purple', 'thistle', 'blueviolet'))
plt.title('Sector-wise Growth in Jobs')
plt.xlabel('Sector')
plt.ylabel('Count')
plt.legend(title='Growth in Jobs', loc='upper right')
plt.show()

# %% [markdown]
# Understanding the factors contributing to job growth in these sectors can inform workforce development strategies, education initiatives, and talent acquisition efforts to support economic growth and innovation in these critical industries.
# > * The financials sector experiencing the highest growth in jobs indicates potential expansion and increased demand for financial services, such as banking, investment, and insurance.
# > * The technology sector's significant growth in jobs reflects the industry's pivotal role in driving innovation, digital transformation, and economic development.
# > * Despite facing challenges such as market volatility and environmental concerns, the energy sector's growth in jobs indicates ongoing demand for energy-related services and initiatives.

# %% [markdown]
# **Note:** It's important to remember that data analysis is an iterative process. While we've extracted insights from the current dataset, there's always potential to delve deeper, extract new insights, and add more dimensions to our analysis. As we continue to explore and refine our understanding of the data, we may uncover valuable patterns, correlations, and trends that can inform decision-making and drive further exploration. Therefore, we can always go forward and extract new insights from the dataset, adding more value to our analysis.
